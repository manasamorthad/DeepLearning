# %% [markdown]
# <a href="https://colab.research.google.com/github/manasamorthad/DeepLearning/blob/main/dl_week4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow numpy

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD,Adagrad,RMSprop,Adadelta,Adam


X = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([[0],[1],[1],[0]])


model = Sequential([
Dense(4,activation='relu',input_shape=(2,)),
Dense(1,activation='sigmoid')
])
#1. Batch Gradient Descent (BGD)
model.compile(optimizer=SGD(learning_rate=0.1),loss='binary_crossentropy')

model.fit(X,y,epochs=10,batch_size=4)
print(model.predict(X))


#2. Stochastic Gradient Descent (SGD)
model.compile(optimizer=SGD(learning_rate=0.1),loss='binary_crossentropy')

model.fit(X,y,epochs=10,batch_size=1)
print(model.predict(X))

#3  MINI BATCH Gradient Descent (SGD)

model.compile(optimizer=SGD(learning_rate=0.1),loss='binary_crossentropy')

model.fit(X,y,epochs=10,batch_size=2)
print(model.predict(X))

#sgd with momentum
model.compile(optimizer=SGD(learning_rate=0.1,momentum=0.9),loss='binary_crossentropy')

model.fit(X,y,epochs=10)
print(model.predict(X))


#sgd with nestrov

model.compile(optimizer=SGD(learning_rate=0.1,momentum=0.9,nesterov=True),
loss='binary_crossentropy')

model.fit(X,y,epochs=10)
print(model.predict(X))

# AdaGrad

model.compile(optimizer=Adagrad(),loss='binary_crossentropy')

model.fit(X,y,epochs=10)
print(model.predict(X))

#Rmsprop

model.compile(optimizer=RMSprop(),loss='binary_crossentropy')

model.fit(X,y,epochs=10)
print(model.predict(X))

#Ada Delta
model.compile(optimizer=Adadelta(),loss='binary_crossentropy')

model.fit(X,y,epochs=10)
print(model.predict(X))
#Adam

model.compile(optimizer=Adam(),loss='binary_crossentropy')

model.fit(X,y,epochs=10)
print(model.predict(X))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 927ms/step - loss: 0.7317
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 619ms/step - loss: 0.7301
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.7280
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.7260
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.7241
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.7222
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.7204
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.7186
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.7171
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.7154
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# [[0.4932864 ]
#  [0.53029567]
#  [0.48021403]
#  [0.5538899 ]]
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7639
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.7558
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.7445
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7445
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.7418
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7341
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.7356
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.7278
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.7210
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.7152
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step
# [[0.4860831 ]
#  [0.4925329 ]
#  [0.4882935 ]
#  [0.46415523]]
# Epoch 1/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.6863
# Epoch 2/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.6767
# Epoch 3/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.6744
# Epoch 4/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.6794
# Epoch 5/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.6698
# Epoch 6/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.6890
# Epoch 7/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.6722
# Epoch 8/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.6626
# Epoch 9/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.6602
# Epoch 10/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.6577
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# [[0.49425066]
#  [0.50023234]
#  [0.51683   ]
#  [0.44289964]]
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 742ms/step - loss: 0.6549
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.6536
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.6511
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.6476
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.6451
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.6422
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.6384
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.6337
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.6288
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.6228
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# [[0.5039694 ]
#  [0.50619406]
#  [0.60806865]
#  [0.4418653 ]]
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 749ms/step - loss: 0.6156
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.6141
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.6136
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.6083
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.6047
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.5987
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.5925
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.5886
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.5813
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.5730
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7af6ec02f6a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# [[0.47913274]
#  [0.48800302]
#  [0.691638  ]
#  [0.40434596]]
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.5641
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.5640
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 0.5639
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.5639
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 0.5638
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.5638
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.5637
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.5637
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.5637
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.5636
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7af6e7fc59e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# [[0.47896782]
#  [0.48788655]
#  [0.6927025 ]
#  [0.40402338]]
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 802ms/step - loss: 0.5636
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.5630
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.5626
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.5622
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.5617
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.5613
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.5610
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.5610
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.5606
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.5602
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step
# [[0.47322586]
#  [0.483956  ]
#  [0.6904218 ]
#  [0.3957054 ]]
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.5602
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.5602
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 0.5602
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 0.5602
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.5602
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.5602
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.5602
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.5602
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.5602
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.5602
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# [[0.4732153 ]
#  [0.48395237]
#  [0.6904069 ]
#  [0.39568233]]
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.5602
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.5598
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.5597
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.5594
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.5592
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.5590
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.5588
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.5586
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.5584
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.5583
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# [[0.46918806]
#  [0.4814781 ]
#  [0.68753237]
#  [0.38942334]]

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.12/dist-packages (1.7.4.5)
# Requirement already satisfied: bleach in /usr/local/lib/python3.12/dist-packages (from kaggle) (6.3.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.12/dist-packages (from kaggle) (2026.2.25)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.12/dist-packages (from kaggle) (3.4.5)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from kaggle) (3.11)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from kaggle) (5.29.6)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.12/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.32.4)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from kaggle) (75.2.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.12/dist-packages (from kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.12/dist-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kaggle) (4.67.3)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.5.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from kaggle) (0.5.1)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

train = pd.read_csv("/content/drive/MyDrive/DL_datasets/sign_mnist_train.csv")
test = pd.read_csv("/content/drive/MyDrive/DL_datasets/sign_mnist_test.csv")

# %%
import numpy as np

X_train = train.drop('label', axis=1).values
y_train = train['label'].values

X_test = test.drop('label', axis=1).values
y_test = test['label'].values
X_train = X_train / 255.0
X_test = X_test / 255.0
X_train = X_train[:5000]
y_train = y_train[:5000]

X_test = X_test[:1000]
y_test = y_test[:1000]

X_train = X_train.reshape(-1,784)
X_test = X_test.reshape(-1,784)
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train,25)
y_test = to_categorical(y_test,25)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential([
Dense(128,activation='relu',input_shape=(784,)),
Dense(64,activation='relu'),
Dense(25,activation='softmax')
])

model.compile(
optimizer='adam',
loss='categorical_crossentropy',
metrics=['accuracy']
)

model.fit(X_train,y_train,epochs=10,batch_size=64)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.1132 - loss: 3.0655
# Epoch 2/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2310 - loss: 2.5673
# Epoch 3/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3440 - loss: 2.1167
# Epoch 4/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4340 - loss: 1.8258
# Epoch 5/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5058 - loss: 1.6510
# Epoch 6/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5540 - loss: 1.4866
# Epoch 7/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5810 - loss: 1.3956
# Epoch 8/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6138 - loss: 1.2795
# Epoch 9/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6450 - loss: 1.1831
# Epoch 10/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6724 - loss: 1.1058

# %%
from tensorflow.keras.optimizers import SGD, Adagrad, RMSprop, Adadelta, Adam

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD, Adagrad, RMSprop, Adadelta, Adam

optimizers = {
    "BGD": SGD(learning_rate=0.01),
    "SGD": SGD(learning_rate=0.01),
    "MiniBatchGD": SGD(learning_rate=0.01),
    "Momentum": SGD(learning_rate=0.01,momentum=0.9),
    "Nesterov": SGD(learning_rate=0.01,momentum=0.9,nesterov=True),
    "Adagrad": Adagrad(),
    "RMSProp": RMSprop(),
    "Adadelta": Adadelta(),
    "Adam": Adam()
}

results = {}

def create_model(optimizer):
    model = Sequential([
        Dense(128,activation='relu',input_shape=(784,)),
        Dense(64,activation='relu'),
        Dense(25,activation='softmax')
    ])
    model.compile(
        optimizer=optimizer,
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

for name,opt in optimizers.items():

    print("Training with",name)

    model = create_model(opt);

    if name == "BGD":
        batch = len(X_train)

    elif name == "SGD":
        batch = 1

    elif name == "MiniBatchGD":
        batch = 32

    else:
        batch = 32

    history = model.fit(
        X_train,
        y_train,
        epochs=5,
        batch_size=batch,
        validation_data=(X_test,y_test),
        verbose=1
    )

    loss,accuracy = model.evaluate(X_test,y_test,verbose=0)

    results[name] = accuracy
# Out:
# Training with BGD
# Epoch 1/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.0378 - loss: 3.4557 - val_accuracy: 0.0440 - val_loss: 3.3646
# Epoch 2/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.0434 - loss: 3.3907 - val_accuracy: 0.0430 - val_loss: 3.3279
# Epoch 3/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.0466 - loss: 3.3474 - val_accuracy: 0.0430 - val_loss: 3.3024
# Epoch 4/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.0464 - loss: 3.3163 - val_accuracy: 0.0470 - val_loss: 3.2839
# Epoch 5/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.0470 - loss: 3.2932 - val_accuracy: 0.0490 - val_loss: 3.2702
# Training with SGD
# Epoch 1/5
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.1138 - loss: 2.9157 - val_accuracy: 0.2750 - val_loss: 2.3334
# Epoch 2/5
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - accuracy: 0.2648 - loss: 2.2168 - val_accuracy: 0.2680 - val_loss: 2.1171
# Epoch 3/5
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - accuracy: 0.3722 - loss: 1.8868 - val_accuracy: 0.4270 - val_loss: 1.7402
# Epoch 4/5
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - accuracy: 0.4376 - loss: 1.6757 - val_accuracy: 0.2140 - val_loss: 2.4576
# Epoch 5/5
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - accuracy: 0.4838 - loss: 1.5323 - val_accuracy: 0.3350 - val_loss: 2.3015
# Training with MiniBatchGD
# Epoch 1/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.0676 - loss: 3.1452 - val_accuracy: 0.0460 - val_loss: 3.1066
# Epoch 2/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.1460 - loss: 3.0010 - val_accuracy: 0.0990 - val_loss: 2.9936
# Epoch 3/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2038 - loss: 2.8400 - val_accuracy: 0.1590 - val_loss: 2.8496
# Epoch 4/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2568 - loss: 2.6644 - val_accuracy: 0.1440 - val_loss: 2.7212
# Epoch 5/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3026 - loss: 2.4851 - val_accuracy: 0.3050 - val_loss: 2.4536
# Training with Momentum
# Epoch 1/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.1256 - loss: 2.9473 - val_accuracy: 0.2340 - val_loss: 2.4095
# Epoch 2/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3192 - loss: 2.1368 - val_accuracy: 0.3600 - val_loss: 1.9872
# Epoch 3/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4066 - loss: 1.7756 - val_accuracy: 0.4410 - val_loss: 1.7541
# Epoch 4/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4710 - loss: 1.5903 - val_accuracy: 0.4660 - val_loss: 1.7782
# Epoch 5/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5326 - loss: 1.3699 - val_accuracy: 0.4750 - val_loss: 1.6673
# Training with Nesterov
# Epoch 1/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.1326 - loss: 2.9233 - val_accuracy: 0.2480 - val_loss: 2.3745
# Epoch 2/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3502 - loss: 2.0323 - val_accuracy: 0.4950 - val_loss: 1.7508
# Epoch 3/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4758 - loss: 1.5881 - val_accuracy: 0.3560 - val_loss: 2.0736
# Epoch 4/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5600 - loss: 1.3215 - val_accuracy: 0.4590 - val_loss: 1.6918
# Epoch 5/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6274 - loss: 1.1267 - val_accuracy: 0.5230 - val_loss: 1.5197
# Training with Adagrad
# Epoch 1/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0368 - loss: 3.2356 - val_accuracy: 0.0400 - val_loss: 3.1942
# Epoch 2/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0704 - loss: 3.1677 - val_accuracy: 0.0430 - val_loss: 3.1754
# Epoch 3/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0986 - loss: 3.1360 - val_accuracy: 0.0750 - val_loss: 3.1454
# Epoch 4/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1160 - loss: 3.1097 - val_accuracy: 0.0720 - val_loss: 3.1316
# Epoch 5/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1398 - loss: 3.0850 - val_accuracy: 0.1080 - val_loss: 3.1077
# Training with RMSProp
# Epoch 1/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0964 - loss: 3.0882 - val_accuracy: 0.0840 - val_loss: 2.9396
# Epoch 2/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2232 - loss: 2.5676 - val_accuracy: 0.2040 - val_loss: 2.4663
# Epoch 3/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3274 - loss: 2.1484 - val_accuracy: 0.2840 - val_loss: 2.2174
# Epoch 4/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3876 - loss: 1.9127 - val_accuracy: 0.2630 - val_loss: 2.5288
# Epoch 5/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4520 - loss: 1.7222 - val_accuracy: 0.4060 - val_loss: 1.8665
# Training with Adadelta
# Epoch 1/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.0508 - loss: 3.3164 - val_accuracy: 0.0590 - val_loss: 3.2881
# Epoch 2/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0698 - loss: 3.2818 - val_accuracy: 0.0590 - val_loss: 3.2655
# Epoch 3/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0764 - loss: 3.2575 - val_accuracy: 0.0520 - val_loss: 3.2508
# Epoch 4/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0770 - loss: 3.2399 - val_accuracy: 0.0620 - val_loss: 3.2403
# Epoch 5/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0798 - loss: 3.2263 - val_accuracy: 0.0550 - val_loss: 3.2324
# Training with Adam
# Epoch 1/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.1166 - loss: 2.9956 - val_accuracy: 0.1680 - val_loss: 2.7690
# Epoch 2/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2616 - loss: 2.4461 - val_accuracy: 0.2770 - val_loss: 2.3570
# Epoch 3/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3852 - loss: 2.0204 - val_accuracy: 0.3730 - val_loss: 1.9343
# Epoch 4/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4594 - loss: 1.7336 - val_accuracy: 0.4280 - val_loss: 1.7586
# Epoch 5/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5070 - loss: 1.5476 - val_accuracy: 0.4590 - val_loss: 1.6410

# %%
for k,v in results.items():
    print(k,"accuracy:",v)
# Out:
# BGD accuracy: 0.04899999871850014
# SGD accuracy: 0.33500000834465027
# MiniBatchGD accuracy: 0.3050000071525574
# Momentum accuracy: 0.4749999940395355
# Nesterov accuracy: 0.5230000019073486
# Adagrad accuracy: 0.1080000028014183
# RMSProp accuracy: 0.4059999883174896
# Adadelta accuracy: 0.054999999701976776
# Adam accuracy: 0.45899999141693115
